# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow

# %%
image = cv2.imread(r"/content/OIP.jpg")

# %%
resized_image = cv2.resize(image, (200, 150))

# %%
angle= 180
rows, cols = image.shape[:2]
rotation_matrix = cv2.getRotationMatrix2D((cols / 2, rows / 2), angle, 1)
rotated_image = cv2.warpAffine(image, rotation_matrix, (cols, rows))

# %%
x, y, w, h= 50, 50, 500,250
cropped_image = image[y:y+h, x:x+w]

# %%
cv2_imshow(image)
cv2_imshow(resized_image)
cv2_imshow(rotated_image)
cv2_imshow(cropped_image)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=1600x1066>
# <PIL.Image.Image image mode=RGB size=200x150>
# <PIL.Image.Image image mode=RGB size=1600x1066>
# <PIL.Image.Image image mode=RGB size=500x250>
